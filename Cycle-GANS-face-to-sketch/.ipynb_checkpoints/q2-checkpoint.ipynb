# %%
import os
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
from glob import glob
import itertools

# %%
# Set random seed for reproducibility
torch.manual_seed(42)
random.seed(42)

# Define hyperparameters
BATCH_SIZE = 4
IMG_SIZE = 256
EPOCHS = 30
LR = 0.0002
BETA1 = 0.5
LAMBDA_CYCLE = 10.0
LAMBDA_IDENTITY = 0.5
NUM_IMAGES = 1000

# Define the dataset paths
train_a = glob('/kaggle/input/person-face-sketches/train/photos/*')[:NUM_IMAGES]
train_b = glob('/kaggle/input/person-face-sketches/train/sketches/*')[:NUM_IMAGES]

# %%
# Custom Dataset
class FaceSketchDataset(Dataset):
    def __init__(self, image_paths, transform=None):
        self.image_paths = image_paths
        self.transform = transform

    def __getitem__(self, index):
        img = Image.open(self.image_paths[index]).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img

    def __len__(self):
        return len(self.image_paths)

# Data transforms
transform = transforms.Compose([
    transforms.Resize(IMG_SIZE),
    transforms.RandomCrop(IMG_SIZE),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Create datasets and dataloaders
dataset_a = FaceSketchDataset(train_a, transform)
dataset_b = FaceSketchDataset(train_b, transform)
dataloader_a = DataLoader(dataset_a, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
dataloader_b = DataLoader(dataset_b, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)

# %%
# Generator architecture
class ResidualBlock(nn.Module):
    def __init__(self, in_features):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(in_features, in_features, 3),
            nn.InstanceNorm2d(in_features),
            nn.ReLU(inplace=True),
            nn.ReflectionPad2d(1),
            nn.Conv2d(in_features, in_features, 3),
            nn.InstanceNorm2d(in_features)
        )

    def forward(self, x):
        return x + self.block(x)

class Generator(nn.Module):
    def __init__(self, input_channels, output_channels, num_residual_blocks=9):
        super(Generator, self).__init__()
        
        # Initial convolution block
        model = [
            nn.ReflectionPad2d(3),
            nn.Conv2d(input_channels, 64, 7),
            nn.InstanceNorm2d(64),
            nn.ReLU(inplace=True)
        ]
        
        # Downsampling
        in_features = 64
        out_features = in_features * 2
        for _ in range(2):
            model += [
                nn.Conv2d(in_features, out_features, 3, stride=2, padding=1),
                nn.InstanceNorm2d(out_features),
                nn.ReLU(inplace=True)
            ]
            in_features = out_features
            out_features = in_features * 2

        # Residual blocks
        for _ in range(num_residual_blocks):
            model += [ResidualBlock(in_features)]

        # Upsampling
        out_features = in_features // 2
        for _ in range(2):
            model += [
                nn.ConvTranspose2d(in_features, out_features, 3, stride=2, padding=1, output_padding=1),
                nn.InstanceNorm2d(out_features),
                nn.ReLU(inplace=True)
            ]
            in_features = out_features
            out_features = in_features // 2

        # Output layer
        model += [nn.ReflectionPad2d(3),
                  nn.Conv2d(64, output_channels, 7),
                  nn.Tanh()]

        self.model = nn.Sequential(*model)

    def forward(self, x):
        return self.model(x)

# %%
# Discriminator architecture
class Discriminator(nn.Module):
    def __init__(self, input_channels):
        super(Discriminator, self).__init__()

        def discriminator_block(in_filters, out_filters, normalize=True):
            layers = [nn.Conv2d(in_filters, out_filters, 4, stride=2, padding=1)]
            if normalize:
                layers.append(nn.InstanceNorm2d(out_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        self.model = nn.Sequential(
            *discriminator_block(input_channels, 64, normalize=False),
            *discriminator_block(64, 128),
            *discriminator_block(128, 256),
            *discriminator_block(256, 512),
            nn.ZeroPad2d((1, 0, 1, 0)),
            nn.Conv2d(512, 1, 4, padding=1)
        )

    def forward(self, x):
        return self.model(x)

# %%
# Initialize models
G_AB = Generator(3, 3).cuda()
G_BA = Generator(3, 3).cuda()
D_A = Discriminator(3).cuda()
D_B = Discriminator(3).cuda()

# Loss functions
criterion_GAN = nn.MSELoss()
criterion_cycle = nn.L1Loss()
criterion_identity = nn.L1Loss()

# Optimizers
optimizer_G = optim.Adam(itertools.chain(G_AB.parameters(), G_BA.parameters()), lr=LR, betas=(BETA1, 0.999))
optimizer_D_A = optim.Adam(D_A.parameters(), lr=LR, betas=(BETA1, 0.999))
optimizer_D_B = optim.Adam(D_B.parameters(), lr=LR, betas=(BETA1, 0.999))

# %%
# Training function
def train(epoch):
    G_AB.train()
    G_BA.train()
    D_A.train()
    D_B.train()

    for i, (real_A, real_B) in enumerate(zip(dataloader_a, dataloader_b)):
        real_A = real_A.cuda()
        real_B = real_B.cuda()

        # Generate fake images
        fake_B = G_AB(real_A)
        fake_A = G_BA(real_B)

        # Train Generators
        optimizer_G.zero_grad()

        # Identity loss
        loss_id_A = criterion_identity(G_BA(real_A), real_A)
        loss_id_B = criterion_identity(G_AB(real_B), real_B)
        loss_identity = (loss_id_A + loss_id_B) * LAMBDA_IDENTITY

        # GAN loss
        loss_GAN_AB = criterion_GAN(D_B(fake_B), torch.ones_like(D_B(fake_B)))
        loss_GAN_BA = criterion_GAN(D_A(fake_A), torch.ones_like(D_A(fake_A)))
        loss_GAN = loss_GAN_AB + loss_GAN_BA

        # Cycle loss
        recov_A = G_BA(fake_B)
        loss_cycle_A = criterion_cycle(recov_A, real_A)
        recov_B = G_AB(fake_A)
        loss_cycle_B = criterion_cycle(recov_B, real_B)
        loss_cycle = (loss_cycle_A + loss_cycle_B) * LAMBDA_CYCLE

        # Total generator loss
        loss_G = loss_GAN + loss_cycle + loss_identity
        loss_G.backward()
        optimizer_G.step()

        # Train Discriminator A
        optimizer_D_A.zero_grad()
        loss_real = criterion_GAN(D_A(real_A), torch.ones_like(D_A(real_A)))
        loss_fake = criterion_GAN(D_A(fake_A.detach()), torch.zeros_like(D_A(fake_A)))
        loss_D_A = (loss_real + loss_fake) * 0.5
        loss_D_A.backward()
        optimizer_D_A.step()

        # Train Discriminator B
        optimizer_D_B.zero_grad()
        loss_real = criterion_GAN(D_B(real_B), torch.ones_like(D_B(real_B)))
        loss_fake = criterion_GAN(D_B(fake_B.detach()), torch.zeros_like(D_B(fake_B)))
        loss_D_B = (loss_real + loss_fake) * 0.5
        loss_D_B.backward()
        optimizer_D_B.step()

        if i % 100 == 0:
            print(f"Epoch [{epoch}/{EPOCHS}] Batch [{i}/{len(dataloader_a)}] "
                  f"Loss D: {(loss_D_A + loss_D_B).item():.4f} "
                  f"Loss G: {loss_G.item():.4f} "
                  f"Loss Cycle: {loss_cycle.item():.4f} "
                  f"Loss Identity: {loss_identity.item():.4f}")

# %%
# Training loop
for epoch in range(EPOCHS):
    train(epoch)
    
    # Save models
    if (epoch + 1) % 10 == 0:
        torch.save(G_AB.state_dict(), f'G_AB_epoch_{epoch+1}.pth')
        torch.save(G_BA.state_dict(), f'G_BA_epoch_{epoch+1}.pth')
        torch.save(D_A.state_dict(), f'D_A_epoch_{epoch+1}.pth')
        torch.save(D_B.state_dict(), f'D_B_epoch_{epoch+1}.pth')
# Out:
# Epoch [0/30] Batch [0/250] Loss D: 1.2401 Loss G: 17.3264 Loss Cycle: 14.4657 Loss Identity: 0.7232
# Epoch [0/30] Batch [100/250] Loss D: 0.3022 Loss G: 5.4187 Loss Cycle: 4.1436 Loss Identity: 0.2373
# Epoch [0/30] Batch [200/250] Loss D: 0.5130 Loss G: 3.2553 Loss Cycle: 2.6979 Loss Identity: 0.1537
# Epoch [1/30] Batch [0/250] Loss D: 0.2819 Loss G: 3.3535 Loss Cycle: 2.3646 Loss Identity: 0.1318
# Epoch [1/30] Batch [100/250] Loss D: 0.4482 Loss G: 3.3681 Loss Cycle: 2.5571 Loss Identity: 0.1332
# Epoch [1/30] Batch [200/250] Loss D: 0.6067 Loss G: 3.8954 Loss Cycle: 2.4576 Loss Identity: 0.1492
# Epoch [2/30] Batch [0/250] Loss D: 0.3366 Loss G: 3.1583 Loss Cycle: 2.1601 Loss Identity: 0.1190
# Epoch [2/30] Batch [100/250] Loss D: 0.3840 Loss G: 3.4999 Loss Cycle: 2.0713 Loss Identity: 0.1276
# Epoch [2/30] Batch [200/250] Loss D: 0.2936 Loss G: 3.6277 Loss Cycle: 2.1393 Loss Identity: 0.1083
# Epoch [3/30] Batch [0/250] Loss D: 0.4100 Loss G: 3.4861 Loss Cycle: 2.5209 Loss Identity: 0.1336
# Epoch [3/30] Batch [100/250] Loss D: 0.2905 Loss G: 2.7174 Loss Cycle: 1.8463 Loss Identity: 0.1160
# Epoch [3/30] Batch [200/250] Loss D: 1.0380 Loss G: 5.3755 Loss Cycle: 2.2854 Loss Identity: 0.1358
# Epoch [4/30] Batch [0/250] Loss D: 0.4576 Loss G: 3.8693 Loss Cycle: 2.0925 Loss Identity: 0.1315
# Epoch [4/30] Batch [100/250] Loss D: 0.5010 Loss G: 5.2727 Loss Cycle: 3.2868 Loss Identity: 0.1920
# Epoch [4/30] Batch [200/250] Loss D: 0.4357 Loss G: 2.3727 Loss Cycle: 1.8291 Loss Identity: 0.0968
# Epoch [5/30] Batch [0/250] Loss D: 0.3356 Loss G: 3.0489 Loss Cycle: 2.1642 Loss Identity: 0.1266
# Epoch [5/30] Batch [100/250] Loss D: 0.4680 Loss G: 2.6161 Loss Cycle: 1.8476 Loss Identity: 0.1083
# Epoch [5/30] Batch [200/250] Loss D: 0.1821 Loss G: 4.0341 Loss Cycle: 2.8685 Loss Identity: 0.1446
# Epoch [6/30] Batch [0/250] Loss D: 0.2931 Loss G: 2.5400 Loss Cycle: 1.6579 Loss Identity: 0.0989
# Epoch [6/30] Batch [100/250] Loss D: 0.2958 Loss G: 2.7925 Loss Cycle: 1.6120 Loss Identity: 0.0895
# Epoch [6/30] Batch [200/250] Loss D: 0.2726 Loss G: 2.8311 Loss Cycle: 1.5951 Loss Identity: 0.0791
# Epoch [7/30] Batch [0/250] Loss D: 0.3624 Loss G: 3.2805 Loss Cycle: 2.2491 Loss Identity: 0.1102
# Epoch [7/30] Batch [100/250] Loss D: 0.2307 Loss G: 3.3330 Loss Cycle: 2.1339 Loss Identity: 0.1346
# Epoch [7/30] Batch [200/250] Loss D: 0.6872 Loss G: 3.1588 Loss Cycle: 2.0409 Loss Identity: 0.1134
# Epoch [8/30] Batch [0/250] Loss D: 0.3356 Loss G: 3.7965 Loss Cycle: 2.0142 Loss Identity: 0.1256
# Epoch [8/30] Batch [100/250] Loss D: 0.3248 Loss G: 2.6366 Loss Cycle: 1.7811 Loss Identity: 0.0857
# Epoch [8/30] Batch [200/250] Loss D: 0.3058 Loss G: 3.2220 Loss Cycle: 2.5026 Loss Identity: 0.1033
# Epoch [9/30] Batch [0/250] Loss D: 0.2523 Loss G: 3.8148 Loss Cycle: 1.9912 Loss Identity: 0.1140
# Epoch [9/30] Batch [100/250] Loss D: 0.1431 Loss G: 4.0247 Loss Cycle: 2.5073 Loss Identity: 0.1041
# Epoch [9/30] Batch [200/250] Loss D: 0.4161 Loss G: 2.2916 Loss Cycle: 1.5950 Loss Identity: 0.0903
# Epoch [10/30] Batch [0/250] Loss D: 0.2867 Loss G: 3.2525 Loss Cycle: 2.0623 Loss Identity: 0.1242
# Epoch [10/30] Batch [100/250] Loss D: 0.2566 Loss G: 3.0146 Loss Cycle: 1.7664 Loss Identity: 0.1074
# Epoch [10/30] Batch [200/250] Loss D: 0.2710 Loss G: 3.5353 Loss Cycle: 2.4177 Loss Identity: 0.1245
# Epoch [11/30] Batch [0/250] Loss D: 0.2347 Loss G: 2.7602 Loss Cycle: 1.7478 Loss Identity: 0.1121
# Epoch [11/30] Batch [100/250] Loss D: 0.4537 Loss G: 2.1808 Loss Cycle: 1.6125 Loss Identity: 0.1099
# Epoch [11/30] Batch [200/250] Loss D: 0.2986 Loss G: 2.7805 Loss Cycle: 1.9256 Loss Identity: 0.1117
# Epoch [12/30] Batch [0/250] Loss D: 0.3689 Loss G: 2.7655 Loss Cycle: 2.0278 Loss Identity: 0.1262
# Epoch [12/30] Batch [100/250] Loss D: 0.3723 Loss G: 2.3329 Loss Cycle: 1.7098 Loss Identity: 0.1050
# Epoch [12/30] Batch [200/250] Loss D: 0.3557 Loss G: 2.5770 Loss Cycle: 1.6008 Loss Identity: 0.0832
# Epoch [13/30] Batch [0/250] Loss D: 0.2593 Loss G: 3.1804 Loss Cycle: 1.9064 Loss Identity: 0.1250
# Epoch [13/30] Batch [100/250] Loss D: 0.6500 Loss G: 2.4602 Loss Cycle: 1.9678 Loss Identity: 0.1377
# Epoch [13/30] Batch [200/250] Loss D: 0.1980 Loss G: 2.7472 Loss Cycle: 1.7197 Loss Identity: 0.1064
# Epoch [14/30] Batch [0/250] Loss D: 0.3344 Loss G: 2.9583 Loss Cycle: 1.7427 Loss Identity: 0.1118
# Epoch [14/30] Batch [100/250] Loss D: 0.2613 Loss G: 2.2663 Loss Cycle: 1.4363 Loss Identity: 0.0840
# Epoch [14/30] Batch [200/250] Loss D: 0.3209 Loss G: 3.1040 Loss Cycle: 1.9630 Loss Identity: 0.1136
# Epoch [15/30] Batch [0/250] Loss D: 0.2595 Loss G: 2.6676 Loss Cycle: 1.6583 Loss Identity: 0.0925
# Epoch [15/30] Batch [100/250] Loss D: 0.4673 Loss G: 3.2505 Loss Cycle: 1.7205 Loss Identity: 0.1086
# Epoch [15/30] Batch [200/250] Loss D: 0.3856 Loss G: 2.2119 Loss Cycle: 1.6294 Loss Identity: 0.0903
# Epoch [16/30] Batch [0/250] Loss D: 0.2286 Loss G: 2.8680 Loss Cycle: 1.7713 Loss Identity: 0.1025
# Epoch [16/30] Batch [100/250] Loss D: 0.2453 Loss G: 3.3979 Loss Cycle: 1.7026 Loss Identity: 0.0924
# Epoch [16/30] Batch [200/250] Loss D: 0.4277 Loss G: 3.2806 Loss Cycle: 2.1221 Loss Identity: 0.1511
# Epoch [17/30] Batch [0/250] Loss D: 0.2981 Loss G: 2.9614 Loss Cycle: 1.7505 Loss Identity: 0.0820
# Epoch [17/30] Batch [100/250] Loss D: 0.2050 Loss G: 3.4287 Loss Cycle: 1.2727 Loss Identity: 0.0622
# Epoch [17/30] Batch [200/250] Loss D: 0.1223 Loss G: 3.7619 Loss Cycle: 2.1690 Loss Identity: 0.1244
# Epoch [18/30] Batch [0/250] Loss D: 0.3354 Loss G: 3.5303 Loss Cycle: 2.2366 Loss Identity: 0.1210
# Epoch [18/30] Batch [100/250] Loss D: 0.2917 Loss G: 3.0818 Loss Cycle: 1.8846 Loss Identity: 0.1021
# Epoch [18/30] Batch [200/250] Loss D: 0.2364 Loss G: 2.9073 Loss Cycle: 1.8738 Loss Identity: 0.0985
# Epoch [19/30] Batch [0/250] Loss D: 1.0310 Loss G: 3.6782 Loss Cycle: 2.0392 Loss Identity: 0.1169
# Epoch [19/30] Batch [100/250] Loss D: 0.3934 Loss G: 2.2463 Loss Cycle: 1.5973 Loss Identity: 0.0860
# Epoch [19/30] Batch [200/250] Loss D: 0.4037 Loss G: 2.3749 Loss Cycle: 1.4206 Loss Identity: 0.0741
# Epoch [20/30] Batch [0/250] Loss D: 0.4754 Loss G: 2.2617 Loss Cycle: 1.7064 Loss Identity: 0.0965
# Epoch [20/30] Batch [100/250] Loss D: 0.3107 Loss G: 2.3650 Loss Cycle: 1.4501 Loss Identity: 0.0779
# Epoch [20/30] Batch [200/250] Loss D: 0.2982 Loss G: 2.3452 Loss Cycle: 1.3471 Loss Identity: 0.0681
# Epoch [21/30] Batch [0/250] Loss D: 0.2269 Loss G: 3.2219 Loss Cycle: 2.0873 Loss Identity: 0.1006
# Epoch [21/30] Batch [100/250] Loss D: 0.2783 Loss G: 3.9290 Loss Cycle: 1.8315 Loss Identity: 0.0901
# Epoch [21/30] Batch [200/250] Loss D: 0.2386 Loss G: 2.5496 Loss Cycle: 1.5678 Loss Identity: 0.0749
# Epoch [22/30] Batch [0/250] Loss D: 0.3532 Loss G: 2.8302 Loss Cycle: 1.5487 Loss Identity: 0.0802
# Epoch [22/30] Batch [100/250] Loss D: 0.1900 Loss G: 2.7618 Loss Cycle: 1.5546 Loss Identity: 0.0779
# Epoch [22/30] Batch [200/250] Loss D: 0.2290 Loss G: 2.6650 Loss Cycle: 1.5344 Loss Identity: 0.1042
# Epoch [23/30] Batch [0/250] Loss D: 0.3696 Loss G: 2.5558 Loss Cycle: 1.4962 Loss Identity: 0.0735
# Epoch [23/30] Batch [100/250] Loss D: 0.3672 Loss G: 2.5818 Loss Cycle: 1.3102 Loss Identity: 0.0586
# Epoch [23/30] Batch [200/250] Loss D: 0.2955 Loss G: 2.4493 Loss Cycle: 1.2562 Loss Identity: 0.0645
# Epoch [24/30] Batch [0/250] Loss D: 0.3065 Loss G: 3.2105 Loss Cycle: 1.9959 Loss Identity: 0.0886
# Epoch [24/30] Batch [100/250] Loss D: 0.2351 Loss G: 2.7773 Loss Cycle: 1.7390 Loss Identity: 0.0950
# Epoch [24/30] Batch [200/250] Loss D: 0.2007 Loss G: 2.7630 Loss Cycle: 1.5110 Loss Identity: 0.0760
# Epoch [25/30] Batch [0/250] Loss D: 0.3491 Loss G: 2.8607 Loss Cycle: 1.4229 Loss Identity: 0.0663
# Epoch [25/30] Batch [100/250] Loss D: 0.3116 Loss G: 2.2809 Loss Cycle: 1.4385 Loss Identity: 0.0728
# Epoch [25/30] Batch [200/250] Loss D: 0.3536 Loss G: 2.5427 Loss Cycle: 1.3284 Loss Identity: 0.0627
# Epoch [26/30] Batch [0/250] Loss D: 0.4179 Loss G: 2.0775 Loss Cycle: 1.3681 Loss Identity: 0.0708
# Epoch [26/30] Batch [100/250] Loss D: 0.6798 Loss G: 4.1500 Loss Cycle: 1.5264 Loss Identity: 0.0706
# Epoch [26/30] Batch [200/250] Loss D: 0.3222 Loss G: 2.6310 Loss Cycle: 1.3513 Loss Identity: 0.0623
# Epoch [27/30] Batch [0/250] Loss D: 0.2332 Loss G: 2.1614 Loss Cycle: 1.3008 Loss Identity: 0.0630
# Epoch [27/30] Batch [100/250] Loss D: 0.1665 Loss G: 2.9888 Loss Cycle: 1.4944 Loss Identity: 0.0754
# Epoch [27/30] Batch [200/250] Loss D: 0.3903 Loss G: 3.1182 Loss Cycle: 1.9218 Loss Identity: 0.0798
# Epoch [28/30] Batch [0/250] Loss D: 0.3314 Loss G: 3.0952 Loss Cycle: 1.6521 Loss Identity: 0.0782
# Epoch [28/30] Batch [100/250] Loss D: 0.1914 Loss G: 2.8827 Loss Cycle: 1.6342 Loss Identity: 0.0762
# Epoch [28/30] Batch [200/250] Loss D: 0.3043 Loss G: 2.4538 Loss Cycle: 1.3325 Loss Identity: 0.0606
# Epoch [29/30] Batch [0/250] Loss D: 0.2550 Loss G: 3.3670 Loss Cycle: 1.8355 Loss Identity: 0.0981
# Epoch [29/30] Batch [100/250] Loss D: 0.3907 Loss G: 2.2814 Loss Cycle: 1.3974 Loss Identity: 0.0668
# Epoch [29/30] Batch [200/250] Loss D: 0.1560 Loss G: 3.2242 Loss Cycle: 1.4945 Loss Identity: 0.0798

# %%
# Test function
def generate_images(G_AB, G_BA, test_A, test_B):
    G_AB.eval()
    G_BA.eval()
    with torch.no_grad():
        fake_B = G_AB(test_A)
        fake_A = G_BA(test_B)
    return fake_A, fake_B

# Load and preprocess test images
test_transform = transforms.Compose([
    transforms.Resize(IMG_SIZE),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
test_A = Image.open('/kaggle/input/person-face-sketches/test/photos/10132.jpg').convert('RGB')
test_B = Image.open('/kaggle/input/person-face-sketches/test/sketches/10132.jpg').convert('RGB')

# test_A = Image.open('/kaggle/input/person-face-sketches/train/photos/8075.jpg').convert('RGB')
# test_B = Image.open('/kaggle/input/person-face-sketches/train/sketches/8075.jpg').convert('RGB')

test_A = test_transform(test_A).unsqueeze(0).cuda()
test_B = test_transform(test_B).unsqueeze(0).cuda()

# Generate images
fake_A, fake_B = generate_images(G_AB, G_BA, test_A, test_B)

# %%
import matplotlib.pyplot as plt
# Convert tensors to images and display
def tensor_to_image(tensor):
    image = tensor.cpu().squeeze().permute(1, 2, 0).detach().numpy()
    image = (image + 1) / 2.0 * 255
    return image.astype('uint8')

plt.figure(figsize=(12, 6))
plt.subplot(221)
plt.imshow(tensor_to_image(test_A))
plt.title('Real Photo')
plt.axis('off')

plt.subplot(222)
plt.imshow(tensor_to_image(fake_B))
plt.title('Generated Sketch')
plt.axis('off')

plt.subplot(223)
plt.imshow(tensor_to_image(test_B))
plt.title('Real Sketch')
plt.axis('off')

plt.subplot(224)
plt.imshow(tensor_to_image(fake_A))
plt.title('Generated Photo')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
for s in train_a:
    print(s)
# Out:
# /kaggle/input/person-face-sketches/train/photos/19812.jpg
# /kaggle/input/person-face-sketches/train/photos/22735.jpg
# /kaggle/input/person-face-sketches/train/photos/16916.jpg
# /kaggle/input/person-face-sketches/train/photos/22706.jpg
# /kaggle/input/person-face-sketches/train/photos/12666.jpg
# /kaggle/input/person-face-sketches/train/photos/13288.jpg
# /kaggle/input/person-face-sketches/train/photos/20088.jpg
# /kaggle/input/person-face-sketches/train/photos/28578.jpg
# /kaggle/input/person-face-sketches/train/photos/22288.jpg
# /kaggle/input/person-face-sketches/train/photos/24819.jpg
# /kaggle/input/person-face-sketches/train/photos/6241.jpg
# /kaggle/input/person-face-sketches/train/photos/25540.jpg
# /kaggle/input/person-face-sketches/train/photos/20529.jpg
# /kaggle/input/person-face-sketches/train/photos/27582.jpg
# /kaggle/input/person-face-sketches/train/photos/623.jpg
# /kaggle/input/person-face-sketches/train/photos/2193.jpg
# /kaggle/input/person-face-sketches/train/photos/14143.jpg
# /kaggle/input/person-face-sketches/train/photos/21440.jpg
# /kaggle/input/person-face-sketches/train/photos/3750.jpg
# /kaggle/input/person-face-sketches/train/photos/11378.jpg
# /kaggle/input/person-face-sketches/train/photos/2008.jpg
# /kaggle/input/person-face-sketches/train/photos/10730.jpg
# /kaggle/input/person-face-sketches/train/photos/17338.jpg
# /kaggle/input/person-face-sketches/train/photos/22608.jpg
# /kaggle/input/person-face-sketches/train/photos/16730.jpg
# /kaggle/input/person-face-sketches/train/photos/5982.jpg
# /kaggle/input/person-face-sketches/train/photos/2081.jpg
# /kaggle/input/person-face-sketches/train/photos/14986.jpg
# /kaggle/input/person-face-sketches/train/photos/10597.jpg
# /kaggle/input/person-face-sketches/train/photos/6588.jpg
# /kaggle/input/person-face-sketches/train/photos/12992.jpg
# /kaggle/input/person-face-sketches/train/photos/7966.jpg
# /kaggle/input/person-face-sketches/train/photos/23149.jpg
# /kaggle/input/person-face-sketches/train/photos/3919.jpg
# /kaggle/input/person-face-sketches/train/photos/6197.jpg
# /kaggle/input/person-face-sketches/train/photos/25184.jpg
# /kaggle/input/person-face-sketches/train/photos/27345.jpg
# /kaggle/input/person-face-sketches/train/photos/26076.jpg
# /kaggle/input/person-face-sketches/train/photos/27577.jpg
# /kaggle/input/person-face-sketches/train/photos/27053.jpg
# /kaggle/input/person-face-sketches/train/photos/3757.jpg
# /kaggle/input/person-face-sketches/train/photos/9131.jpg
# /kaggle/input/person-face-sketches/train/photos/13856.jpg
# /kaggle/input/person-face-sketches/train/photos/26072.jpg
# /kaggle/input/person-face-sketches/train/photos/9620.jpg
# /kaggle/input/person-face-sketches/train/photos/9062.jpg
# /kaggle/input/person-face-sketches/train/photos/4489.jpg
# /kaggle/input/person-face-sketches/train/photos/3138.jpg
# /kaggle/input/person-face-sketches/train/photos/10213.jpg
# /kaggle/input/person-face-sketches/train/photos/3417.jpg
# /kaggle/input/person-face-sketches/train/photos/6074.jpg
# /kaggle/input/person-face-sketches/train/photos/29970.jpg
# /kaggle/input/person-face-sketches/train/photos/26623.jpg
# /kaggle/input/person-face-sketches/train/photos/19674.jpg
# /kaggle/input/person-face-sketches/train/photos/29112.jpg
# /kaggle/input/person-face-sketches/train/photos/28165.jpg
# /kaggle/input/person-face-sketches/train/photos/28204.jpg
# /kaggle/input/person-face-sketches/train/photos/5307.jpg
# /kaggle/input/person-face-sketches/train/photos/10305.jpg
# /kaggle/input/person-face-sketches/train/photos/4407.jpg
# /kaggle/input/person-face-sketches/train/photos/1700.jpg
# /kaggle/input/person-face-sketches/train/photos/17257.jpg
# /kaggle/input/person-face-sketches/train/photos/17720.jpg
# /kaggle/input/person-face-sketches/train/photos/2907.jpg
# /kaggle/input/person-face-sketches/train/photos/8930.jpg
# /kaggle/input/person-face-sketches/train/photos/11138.jpg
# /kaggle/input/person-face-sketches/train/photos/16257.jpg
# /kaggle/input/person-face-sketches/train/photos/25501.jpg
# /kaggle/input/person-face-sketches/train/photos/15979.jpg
# /kaggle/input/person-face-sketches/train/photos/18516.jpg
# /kaggle/input/person-face-sketches/train/photos/28375.jpg
# /kaggle/input/person-face-sketches/train/photos/5584.jpg
# /kaggle/input/person-face-sketches/train/photos/27973.jpg
# /kaggle/input/person-face-sketches/train/photos/10627.jpg
# /kaggle/input/person-face-sketches/train/photos/3501.jpg
# /kaggle/input/person-face-sketches/train/photos/2863.jpg
# /kaggle/input/person-face-sketches/train/photos/771.jpg
# /kaggle/input/person-face-sketches/train/photos/8352.jpg
# /kaggle/input/person-face-sketches/train/photos/208.jpg
# /kaggle/input/person-face-sketches/train/photos/23775.jpg
# /kaggle/input/person-face-sketches/train/photos/12167.jpg
# /kaggle/input/person-face-sketches/train/photos/17643.jpg
# /kaggle/input/person-face-sketches/train/photos/28726.jpg
# /kaggle/input/person-face-sketches/train/photos/22046.jpg
# /kaggle/input/person-face-sketches/train/photos/29411.jpg
# /kaggle/input/person-face-sketches/train/photos/11868.jpg
# /kaggle/input/person-face-sketches/train/photos/26853.jpg
# /kaggle/input/person-face-sketches/train/photos/20938.jpg
# /kaggle/input/person-face-sketches/train/photos/4640.jpg
# /kaggle/input/person-face-sketches/train/photos/21590.jpg
# /kaggle/input/person-face-sketches/train/photos/26538.jpg
# /kaggle/input/person-face-sketches/train/photos/17672.jpg
# /kaggle/input/person-face-sketches/train/photos/15082.jpg
# /kaggle/input/person-face-sketches/train/photos/5333.jpg
# /kaggle/input/person-face-sketches/train/photos/4125.jpg
# /kaggle/input/person-face-sketches/train/photos/14312.jpg
# /kaggle/input/person-face-sketches/train/photos/24667.jpg
# /kaggle/input/person-face-sketches/train/photos/25858.jpg
# /kaggle/input/person-face-sketches/train/photos/23436.jpg
# /kaggle/input/person-face-sketches/train/photos/26518.jpg
# /kaggle/input/person-face-sketches/train/photos/21575.jpg
# /kaggle/input/person-face-sketches/train/photos/23710.jpg
# /kaggle/input/person-face-sketches/train/photos/22604.jpg
# /kaggle/input/person-face-sketches/train/photos/10162.jpg
# /kaggle/input/person-face-sketches/train/photos/28686.jpg
# /kaggle/input/person-face-sketches/train/photos/15572.jpg
# /kaggle/input/person-face-sketches/train/photos/19901.jpg
# /kaggle/input/person-face-sketches/train/photos/25261.jpg
# /kaggle/input/person-face-sketches/train/photos/13333.jpg
# /kaggle/input/person-face-sketches/train/photos/4009.jpg
# /kaggle/input/person-face-sketches/train/photos/9645.jpg
# /kaggle/input/person-face-sketches/train/photos/15823.jpg
# /kaggle/input/person-face-sketches/train/photos/14395.jpg
# /kaggle/input/person-face-sketches/train/photos/25171.jpg
# /kaggle/input/person-face-sketches/train/photos/9579.jpg
# /kaggle/input/person-face-sketches/train/photos/20833.jpg
# /kaggle/input/person-face-sketches/train/photos/820.jpg
# /kaggle/input/person-face-sketches/train/photos/3228.jpg
# /kaggle/input/person-face-sketches/train/photos/12132.jpg
# /kaggle/input/person-face-sketches/train/photos/20684.jpg
# /kaggle/input/person-face-sketches/train/photos/8075.jpg
# /kaggle/input/person-face-sketches/train/photos/26475.jpg
# /kaggle/input/person-face-sketches/train/photos/6272.jpg
# /kaggle/input/person-face-sketches/train/photos/1789.jpg
# /kaggle/input/person-face-sketches/train/photos/25869.jpg
# /kaggle/input/person-face-sketches/train/photos/6459.jpg
# /kaggle/input/person-face-sketches/train/photos/23753.jpg
# /kaggle/input/person-face-sketches/train/photos/7690.jpg
# /kaggle/input/person-face-sketches/train/photos/21966.jpg
# /kaggle/input/person-face-sketches/train/photos/15783.jpg
# /kaggle/input/person-face-sketches/train/photos/6653.jpg
# /kaggle/input/person-face-sketches/train/photos/23566.jpg
# /kaggle/input/person-face-sketches/train/photos/16385.jpg
# /kaggle/input/person-face-sketches/train/photos/473.jpg
# /kaggle/input/person-face-sketches/train/photos/8864.jpg
# /kaggle/input/person-face-sketches/train/photos/12768.jpg
# /kaggle/input/person-face-sketches/train/photos/23474.jpg
# /kaggle/input/person-face-sketches/train/photos/3446.jpg
# /kaggle/input/person-face-sketches/train/photos/11034.jpg
# /kaggle/input/person-face-sketches/train/photos/1792.jpg
# /kaggle/input/person-face-sketches/train/photos/4772.jpg
# /kaggle/input/person-face-sketches/train/photos/16016.jpg
# /kaggle/input/person-face-sketches/train/photos/26591.jpg
# /kaggle/input/person-face-sketches/train/photos/7427.jpg
# /kaggle/input/person-face-sketches/train/photos/24692.jpg
# /kaggle/input/person-face-sketches/train/photos/8623.jpg
# /kaggle/input/person-face-sketches/train/photos/23273.jpg
# /kaggle/input/person-face-sketches/train/photos/28271.jpg
# /kaggle/input/person-face-sketches/train/photos/2936.jpg
# /kaggle/input/person-face-sketches/train/photos/2029.jpg
# /kaggle/input/person-face-sketches/train/photos/13118.jpg
# /kaggle/input/person-face-sketches/train/photos/6925.jpg
# /kaggle/input/person-face-sketches/train/photos/26803.jpg
# /kaggle/input/person-face-sketches/train/photos/4313.jpg
# /kaggle/input/person-face-sketches/train/photos/23031.jpg
# /kaggle/input/person-face-sketches/train/photos/6295.jpg
# /kaggle/input/person-face-sketches/train/photos/20010.jpg
# /kaggle/input/person-face-sketches/train/photos/5018.jpg
# /kaggle/input/person-face-sketches/train/photos/27092.jpg
# /kaggle/input/person-face-sketches/train/photos/24487.jpg
# /kaggle/input/person-face-sketches/train/photos/13205.jpg
# /kaggle/input/person-face-sketches/train/photos/10201.jpg
# /kaggle/input/person-face-sketches/train/photos/8914.jpg
# /kaggle/input/person-face-sketches/train/photos/11251.jpg
# /kaggle/input/person-face-sketches/train/photos/1411.jpg
# /kaggle/input/person-face-sketches/train/photos/23098.jpg
# /kaggle/input/person-face-sketches/train/photos/7918.jpg
# /kaggle/input/person-face-sketches/train/photos/4275.jpg
# /kaggle/input/person-face-sketches/train/photos/7245.jpg
# /kaggle/input/person-face-sketches/train/photos/24392.jpg
# /kaggle/input/person-face-sketches/train/photos/24350.jpg
# /kaggle/input/person-face-sketches/train/photos/20100.jpg
# /kaggle/input/person-face-sketches/train/photos/29977.jpg
# /kaggle/input/person-face-sketches/train/photos/22711.jpg
# /kaggle/input/person-face-sketches/train/photos/3532.jpg
# /kaggle/input/person-face-sketches/train/photos/20789.jpg
# /kaggle/input/person-face-sketches/train/photos/7802.jpg
# /kaggle/input/person-face-sketches/train/photos/1031.jpg
# /kaggle/input/person-face-sketches/train/photos/20076.jpg
# /kaggle/input/person-face-sketches/train/photos/23258.jpg
# /kaggle/input/person-face-sketches/train/photos/14897.jpg
# /kaggle/input/person-face-sketches/train/photos/23220.jpg
# /kaggle/input/person-face-sketches/train/photos/2675.jpg
# /kaggle/input/person-face-sketches/train/photos/5627.jpg
# /kaggle/input/person-face-sketches/train/photos/6800.jpg
# /kaggle/input/person-face-sketches/train/photos/7962.jpg
# /kaggle/input/person-face-sketches/train/photos/25779.jpg
# /kaggle/input/person-face-sketches/train/photos/23094.jpg
# /kaggle/input/person-face-sketches/train/photos/27613.jpg
# /kaggle/input/person-face-sketches/train/photos/10255.jpg
# /kaggle/input/person-face-sketches/train/photos/12414.jpg
# /kaggle/input/person-face-sketches/train/photos/18945.jpg
# /kaggle/input/person-face-sketches/train/photos/28806.jpg
# /kaggle/input/person-face-sketches/train/photos/25469.jpg
# /kaggle/input/person-face-sketches/train/photos/24969.jpg
# /kaggle/input/person-face-sketches/train/photos/21232.jpg
# /kaggle/input/person-face-sketches/train/photos/20321.jpg
# /kaggle/input/person-face-sketches/train/photos/13049.jpg
# /kaggle/input/person-face-sketches/train/photos/28516.jpg
# /kaggle/input/person-face-sketches/train/photos/11236.jpg
# /kaggle/input/person-face-sketches/train/photos/12267.jpg
# /kaggle/input/person-face-sketches/train/photos/2172.jpg
# /kaggle/input/person-face-sketches/train/photos/18227.jpg
# /kaggle/input/person-face-sketches/train/photos/25990.jpg
# /kaggle/input/person-face-sketches/train/photos/21588.jpg
# /kaggle/input/person-face-sketches/train/photos/21947.jpg
# /kaggle/input/person-face-sketches/train/photos/6209.jpg
# /kaggle/input/person-face-sketches/train/photos/6899.jpg
# /kaggle/input/person-face-sketches/train/photos/8442.jpg
# /kaggle/input/person-face-sketches/train/photos/11522.jpg
# /kaggle/input/person-face-sketches/train/photos/11529.jpg
# /kaggle/input/person-face-sketches/train/photos/6229.jpg
# /kaggle/input/person-face-sketches/train/photos/28319.jpg
# /kaggle/input/person-face-sketches/train/photos/1749.jpg
# /kaggle/input/person-face-sketches/train/photos/1501.jpg
# /kaggle/input/person-face-sketches/train/photos/9606.jpg
# /kaggle/input/person-face-sketches/train/photos/2021.jpg
# /kaggle/input/person-face-sketches/train/photos/29648.jpg
# /kaggle/input/person-face-sketches/train/photos/15360.jpg
# /kaggle/input/person-face-sketches/train/photos/29764.jpg
# /kaggle/input/person-face-sketches/train/photos/11855.jpg
# /kaggle/input/person-face-sketches/train/photos/14328.jpg
# /kaggle/input/person-face-sketches/train/photos/25310.jpg
# /kaggle/input/person-face-sketches/train/photos/17190.jpg
# /kaggle/input/person-face-sketches/train/photos/5886.jpg
# /kaggle/input/person-face-sketches/train/photos/24778.jpg
# /kaggle/input/person-face-sketches/train/photos/13314.jpg
# /kaggle/input/person-face-sketches/train/photos/16652.jpg
# /kaggle/input/person-face-sketches/train/photos/3899.jpg
# /kaggle/input/person-face-sketches/train/photos/29223.jpg
# /kaggle/input/person-face-sketches/train/photos/27376.jpg
# /kaggle/input/person-face-sketches/train/photos/24917.jpg
# /kaggle/input/person-face-sketches/train/photos/1995.jpg
# /kaggle/input/person-face-sketches/train/photos/20978.jpg
# /kaggle/input/person-face-sketches/train/photos/24068.jpg
# /kaggle/input/person-face-sketches/train/photos/1385.jpg
# /kaggle/input/person-face-sketches/train/photos/3651.jpg
# /kaggle/input/person-face-sketches/train/photos/8342.jpg
# /kaggle/input/person-face-sketches/train/photos/18048.jpg
# /kaggle/input/person-face-sketches/train/photos/15103.jpg
# /kaggle/input/person-face-sketches/train/photos/7544.jpg
# /kaggle/input/person-face-sketches/train/photos/4398.jpg
# /kaggle/input/person-face-sketches/train/photos/19407.jpg
# /kaggle/input/person-face-sketches/train/photos/4581.jpg
# /kaggle/input/person-face-sketches/train/photos/16504.jpg
# /kaggle/input/person-face-sketches/train/photos/20429.jpg
# /kaggle/input/person-face-sketches/train/photos/3537.jpg
# /kaggle/input/person-face-sketches/train/photos/21946.jpg
# /kaggle/input/person-face-sketches/train/photos/28604.jpg
# /kaggle/input/person-face-sketches/train/photos/16638.jpg
# /kaggle/input/person-face-sketches/train/photos/5575.jpg
# /kaggle/input/person-face-sketches/train/photos/20825.jpg
# /kaggle/input/person-face-sketches/train/photos/2278.jpg
# /kaggle/input/person-face-sketches/train/photos/21701.jpg
# /kaggle/input/person-face-sketches/train/photos/26474.jpg
# /kaggle/input/person-face-sketches/train/photos/28621.jpg
# /kaggle/input/person-face-sketches/train/photos/25558.jpg
# /kaggle/input/person-face-sketches/train/photos/12675.jpg
# /kaggle/input/person-face-sketches/train/photos/17474.jpg
# /kaggle/input/person-face-sketches/train/photos/20906.jpg
# /kaggle/input/person-face-sketches/train/photos/29360.jpg
# /kaggle/input/person-face-sketches/train/photos/15785.jpg
# /kaggle/input/person-face-sketches/train/photos/24785.jpg
# /kaggle/input/person-face-sketches/train/photos/14619.jpg
# /kaggle/input/person-face-sketches/train/photos/20308.jpg
# /kaggle/input/person-face-sketches/train/photos/18399.jpg
# /kaggle/input/person-face-sketches/train/photos/18700.jpg
# /kaggle/input/person-face-sketches/train/photos/29345.jpg
# /kaggle/input/person-face-sketches/train/photos/27186.jpg
# /kaggle/input/person-face-sketches/train/photos/1971.jpg
# /kaggle/input/person-face-sketches/train/photos/12882.jpg
# /kaggle/input/person-face-sketches/train/photos/27768.jpg
# /kaggle/input/person-face-sketches/train/photos/7061.jpg
# /kaggle/input/person-face-sketches/train/photos/28797.jpg
# /kaggle/input/person-face-sketches/train/photos/26320.jpg
# /kaggle/input/person-face-sketches/train/photos/26291.jpg
# /kaggle/input/person-face-sketches/train/photos/16993.jpg
# /kaggle/input/person-face-sketches/train/photos/21093.jpg
# /kaggle/input/person-face-sketches/train/photos/3807.jpg
# /kaggle/input/person-face-sketches/train/photos/1383.jpg
# /kaggle/input/person-face-sketches/train/photos/15463.jpg
# /kaggle/input/person-face-sketches/train/photos/9887.jpg
# /kaggle/input/person-face-sketches/train/photos/6337.jpg
# /kaggle/input/person-face-sketches/train/photos/8612.jpg
# /kaggle/input/person-face-sketches/train/photos/20760.jpg
# /kaggle/input/person-face-sketches/train/photos/12588.jpg
# /kaggle/input/person-face-sketches/train/photos/13422.jpg
# /kaggle/input/person-face-sketches/train/photos/16654.jpg
# /kaggle/input/person-face-sketches/train/photos/333.jpg
# /kaggle/input/person-face-sketches/train/photos/8379.jpg
# /kaggle/input/person-face-sketches/train/photos/1354.jpg
# /kaggle/input/person-face-sketches/train/photos/11087.jpg
# /kaggle/input/person-face-sketches/train/photos/25902.jpg
# /kaggle/input/person-face-sketches/train/photos/5976.jpg
# /kaggle/input/person-face-sketches/train/photos/1024.jpg
# /kaggle/input/person-face-sketches/train/photos/537.jpg
# /kaggle/input/person-face-sketches/train/photos/7706.jpg
# /kaggle/input/person-face-sketches/train/photos/18013.jpg
# /kaggle/input/person-face-sketches/train/photos/10039.jpg
# /kaggle/input/person-face-sketches/train/photos/25142.jpg
# /kaggle/input/person-face-sketches/train/photos/3014.jpg
# /kaggle/input/person-face-sketches/train/photos/13377.jpg
# /kaggle/input/person-face-sketches/train/photos/22118.jpg
# /kaggle/input/person-face-sketches/train/photos/17587.jpg
# /kaggle/input/person-face-sketches/train/photos/16481.jpg
# /kaggle/input/person-face-sketches/train/photos/28083.jpg
# /kaggle/input/person-face-sketches/train/photos/5147.jpg
# /kaggle/input/person-face-sketches/train/photos/45.jpg
# /kaggle/input/person-face-sketches/train/photos/29028.jpg
# /kaggle/input/person-face-sketches/train/photos/2375.jpg
# /kaggle/input/person-face-sketches/train/photos/7941.jpg
# /kaggle/input/person-face-sketches/train/photos/10550.jpg
# /kaggle/input/person-face-sketches/train/photos/9486.jpg
# /kaggle/input/person-face-sketches/train/photos/25532.jpg
# /kaggle/input/person-face-sketches/train/photos/369.jpg
# /kaggle/input/person-face-sketches/train/photos/22666.jpg
# /kaggle/input/person-face-sketches/train/photos/1626.jpg
# /kaggle/input/person-face-sketches/train/photos/27921.jpg
# /kaggle/input/person-face-sketches/train/photos/28245.jpg
# /kaggle/input/person-face-sketches/train/photos/6493.jpg
# /kaggle/input/person-face-sketches/train/photos/18311.jpg
# /kaggle/input/person-face-sketches/train/photos/5734.jpg
# /kaggle/input/person-face-sketches/train/photos/13673.jpg
# /kaggle/input/person-face-sketches/train/photos/27604.jpg
# /kaggle/input/person-face-sketches/train/photos/16943.jpg
# /kaggle/input/person-face-sketches/train/photos/23082.jpg
# /kaggle/input/person-face-sketches/train/photos/6797.jpg
# /kaggle/input/person-face-sketches/train/photos/20987.jpg
# /kaggle/input/person-face-sketches/train/photos/8444.jpg
# /kaggle/input/person-face-sketches/train/photos/20937.jpg
# /kaggle/input/person-face-sketches/train/photos/654.jpg
# /kaggle/input/person-face-sketches/train/photos/10598.jpg
# /kaggle/input/person-face-sketches/train/photos/26688.jpg
# /kaggle/input/person-face-sketches/train/photos/4437.jpg
# /kaggle/input/person-face-sketches/train/photos/25943.jpg
# /kaggle/input/person-face-sketches/train/photos/13614.jpg
# /kaggle/input/person-face-sketches/train/photos/24439.jpg
# /kaggle/input/person-face-sketches/train/photos/20267.jpg
# /kaggle/input/person-face-sketches/train/photos/9462.jpg
# /kaggle/input/person-face-sketches/train/photos/16723.jpg
# /kaggle/input/person-face-sketches/train/photos/29153.jpg
# /kaggle/input/person-face-sketches/train/photos/27808.jpg
# /kaggle/input/person-face-sketches/train/photos/19792.jpg
# /kaggle/input/person-face-sketches/train/photos/22945.jpg
# /kaggle/input/person-face-sketches/train/photos/26297.jpg
# /kaggle/input/person-face-sketches/train/photos/8643.jpg
# /kaggle/input/person-face-sketches/train/photos/9493.jpg
# /kaggle/input/person-face-sketches/train/photos/13400.jpg
# /kaggle/input/person-face-sketches/train/photos/21493.jpg
# /kaggle/input/person-face-sketches/train/photos/89.jpg
# /kaggle/input/person-face-sketches/train/photos/11428.jpg
# /kaggle/input/person-face-sketches/train/photos/19888.jpg
# /kaggle/input/person-face-sketches/train/photos/6367.jpg
# /kaggle/input/person-face-sketches/train/photos/18638.jpg
# /kaggle/input/person-face-sketches/train/photos/5853.jpg
# /kaggle/input/person-face-sketches/train/photos/12068.jpg
# /kaggle/input/person-face-sketches/train/photos/15578.jpg
# /kaggle/input/person-face-sketches/train/photos/28895.jpg
# /kaggle/input/person-face-sketches/train/photos/20475.jpg
# /kaggle/input/person-face-sketches/train/photos/26201.jpg
# /kaggle/input/person-face-sketches/train/photos/5534.jpg
# /kaggle/input/person-face-sketches/train/photos/20.jpg
# /kaggle/input/person-face-sketches/train/photos/25241.jpg
# /kaggle/input/person-face-sketches/train/photos/7516.jpg
# /kaggle/input/person-face-sketches/train/photos/9083.jpg
# /kaggle/input/person-face-sketches/train/photos/21612.jpg
# /kaggle/input/person-face-sketches/train/photos/14510.jpg
# /kaggle/input/person-face-sketches/train/photos/27891.jpg
# /kaggle/input/person-face-sketches/train/photos/22742.jpg
# /kaggle/input/person-face-sketches/train/photos/12101.jpg
# /kaggle/input/person-face-sketches/train/photos/15911.jpg
# /kaggle/input/person-face-sketches/train/photos/12205.jpg
# /kaggle/input/person-face-sketches/train/photos/9251.jpg
# /kaggle/input/person-face-sketches/train/photos/21126.jpg
# /kaggle/input/person-face-sketches/train/photos/8003.jpg
# /kaggle/input/person-face-sketches/train/photos/18702.jpg
# /kaggle/input/person-face-sketches/train/photos/29670.jpg
# /kaggle/input/person-face-sketches/train/photos/4351.jpg
# /kaggle/input/person-face-sketches/train/photos/14141.jpg
# /kaggle/input/person-face-sketches/train/photos/10062.jpg
# /kaggle/input/person-face-sketches/train/photos/24287.jpg
# /kaggle/input/person-face-sketches/train/photos/20079.jpg
# /kaggle/input/person-face-sketches/train/photos/9589.jpg
# /kaggle/input/person-face-sketches/train/photos/20762.jpg
# /kaggle/input/person-face-sketches/train/photos/27881.jpg
# /kaggle/input/person-face-sketches/train/photos/24065.jpg
# /kaggle/input/person-face-sketches/train/photos/23412.jpg
# /kaggle/input/person-face-sketches/train/photos/22798.jpg
# /kaggle/input/person-face-sketches/train/photos/19251.jpg
# /kaggle/input/person-face-sketches/train/photos/10075.jpg
# /kaggle/input/person-face-sketches/train/photos/3670.jpg
# /kaggle/input/person-face-sketches/train/photos/13598.jpg
# /kaggle/input/person-face-sketches/train/photos/19727.jpg
# /kaggle/input/person-face-sketches/train/photos/5882.jpg
# /kaggle/input/person-face-sketches/train/photos/20042.jpg
# /kaggle/input/person-face-sketches/train/photos/2532.jpg
# /kaggle/input/person-face-sketches/train/photos/11058.jpg
# /kaggle/input/person-face-sketches/train/photos/17091.jpg
# /kaggle/input/person-face-sketches/train/photos/1161.jpg
# /kaggle/input/person-face-sketches/train/photos/11849.jpg
# /kaggle/input/person-face-sketches/train/photos/9868.jpg
# /kaggle/input/person-face-sketches/train/photos/22108.jpg
# /kaggle/input/person-face-sketches/train/photos/14103.jpg
# /kaggle/input/person-face-sketches/train/photos/13624.jpg
# /kaggle/input/person-face-sketches/train/photos/26541.jpg
# /kaggle/input/person-face-sketches/train/photos/18482.jpg
# /kaggle/input/person-face-sketches/train/photos/18708.jpg
# /kaggle/input/person-face-sketches/train/photos/23819.jpg
# /kaggle/input/person-face-sketches/train/photos/9336.jpg
# /kaggle/input/person-face-sketches/train/photos/25195.jpg
# /kaggle/input/person-face-sketches/train/photos/3645.jpg
# /kaggle/input/person-face-sketches/train/photos/1940.jpg
# /kaggle/input/person-face-sketches/train/photos/1777.jpg
# /kaggle/input/person-face-sketches/train/photos/8328.jpg
# /kaggle/input/person-face-sketches/train/photos/16360.jpg
# /kaggle/input/person-face-sketches/train/photos/9999.jpg
# /kaggle/input/person-face-sketches/train/photos/29213.jpg
# /kaggle/input/person-face-sketches/train/photos/19833.jpg
# /kaggle/input/person-face-sketches/train/photos/15953.jpg
# /kaggle/input/person-face-sketches/train/photos/11690.jpg
# /kaggle/input/person-face-sketches/train/photos/11524.jpg
# /kaggle/input/person-face-sketches/train/photos/27220.jpg
# /kaggle/input/person-face-sketches/train/photos/6924.jpg
# /kaggle/input/person-face-sketches/train/photos/24355.jpg
# /kaggle/input/person-face-sketches/train/photos/16679.jpg
# /kaggle/input/person-face-sketches/train/photos/212.jpg
# /kaggle/input/person-face-sketches/train/photos/19998.jpg
# /kaggle/input/person-face-sketches/train/photos/5482.jpg
# /kaggle/input/person-face-sketches/train/photos/29346.jpg
# /kaggle/input/person-face-sketches/train/photos/5852.jpg
# /kaggle/input/person-face-sketches/train/photos/239.jpg
# /kaggle/input/person-face-sketches/train/photos/792.jpg
# /kaggle/input/person-face-sketches/train/photos/24083.jpg
# /kaggle/input/person-face-sketches/train/photos/2057.jpg
# /kaggle/input/person-face-sketches/train/photos/25153.jpg
# /kaggle/input/person-face-sketches/train/photos/1009.jpg
# /kaggle/input/person-face-sketches/train/photos/21278.jpg
# /kaggle/input/person-face-sketches/train/photos/21582.jpg
# /kaggle/input/person-face-sketches/train/photos/19747.jpg
# /kaggle/input/person-face-sketches/train/photos/3295.jpg
# /kaggle/input/person-face-sketches/train/photos/28734.jpg
# /kaggle/input/person-face-sketches/train/photos/25069.jpg
# /kaggle/input/person-face-sketches/train/photos/25006.jpg
# /kaggle/input/person-face-sketches/train/photos/16406.jpg
# /kaggle/input/person-face-sketches/train/photos/25997.jpg
# /kaggle/input/person-face-sketches/train/photos/26855.jpg
# /kaggle/input/person-face-sketches/train/photos/15317.jpg
# /kaggle/input/person-face-sketches/train/photos/27627.jpg
# /kaggle/input/person-face-sketches/train/photos/27836.jpg
# /kaggle/input/person-face-sketches/train/photos/23351.jpg
# /kaggle/input/person-face-sketches/train/photos/14737.jpg
# /kaggle/input/person-face-sketches/train/photos/13737.jpg
# /kaggle/input/person-face-sketches/train/photos/8592.jpg
# /kaggle/input/person-face-sketches/train/photos/5941.jpg
# /kaggle/input/person-face-sketches/train/photos/24036.jpg
# /kaggle/input/person-face-sketches/train/photos/5158.jpg
# /kaggle/input/person-face-sketches/train/photos/21207.jpg
# /kaggle/input/person-face-sketches/train/photos/23906.jpg
# /kaggle/input/person-face-sketches/train/photos/25547.jpg
# /kaggle/input/person-face-sketches/train/photos/19596.jpg
# /kaggle/input/person-face-sketches/train/photos/3937.jpg
# /kaggle/input/person-face-sketches/train/photos/21808.jpg
# /kaggle/input/person-face-sketches/train/photos/19079.jpg
# /kaggle/input/person-face-sketches/train/photos/28715.jpg
# /kaggle/input/person-face-sketches/train/photos/17796.jpg
# /kaggle/input/person-face-sketches/train/photos/24343.jpg
# /kaggle/input/person-face-sketches/train/photos/10651.jpg
# /kaggle/input/person-face-sketches/train/photos/10880.jpg
# /kaggle/input/person-face-sketches/train/photos/18451.jpg
# /kaggle/input/person-face-sketches/train/photos/2094.jpg
# /kaggle/input/person-face-sketches/train/photos/1157.jpg
# /kaggle/input/person-face-sketches/train/photos/18426.jpg
# /kaggle/input/person-face-sketches/train/photos/58.jpg
# /kaggle/input/person-face-sketches/train/photos/2302.jpg
# /kaggle/input/person-face-sketches/train/photos/13928.jpg
# /kaggle/input/person-face-sketches/train/photos/21495.jpg
# /kaggle/input/person-face-sketches/train/photos/12421.jpg
# /kaggle/input/person-face-sketches/train/photos/26922.jpg
# /kaggle/input/person-face-sketches/train/photos/6190.jpg
# /kaggle/input/person-face-sketches/train/photos/17959.jpg
# /kaggle/input/person-face-sketches/train/photos/17291.jpg
# /kaggle/input/person-face-sketches/train/photos/8340.jpg
# /kaggle/input/person-face-sketches/train/photos/13217.jpg
# /kaggle/input/person-face-sketches/train/photos/3816.jpg
# /kaggle/input/person-face-sketches/train/photos/2695.jpg
# /kaggle/input/person-face-sketches/train/photos/13420.jpg
# /kaggle/input/person-face-sketches/train/photos/29267.jpg
# /kaggle/input/person-face-sketches/train/photos/22356.jpg
# /kaggle/input/person-face-sketches/train/photos/24731.jpg
# /kaggle/input/person-face-sketches/train/photos/19465.jpg
# /kaggle/input/person-face-sketches/train/photos/20578.jpg
# /kaggle/input/person-face-sketches/train/photos/1304.jpg
# /kaggle/input/person-face-sketches/train/photos/21392.jpg
# /kaggle/input/person-face-sketches/train/photos/7512.jpg
# /kaggle/input/person-face-sketches/train/photos/6796.jpg
# /kaggle/input/person-face-sketches/train/photos/11024.jpg
# /kaggle/input/person-face-sketches/train/photos/25145.jpg
# /kaggle/input/person-face-sketches/train/photos/25005.jpg
# /kaggle/input/person-face-sketches/train/photos/14476.jpg
# /kaggle/input/person-face-sketches/train/photos/23881.jpg
# /kaggle/input/person-face-sketches/train/photos/1340.jpg
# /kaggle/input/person-face-sketches/train/photos/24944.jpg
# /kaggle/input/person-face-sketches/train/photos/21809.jpg
# /kaggle/input/person-face-sketches/train/photos/1760.jpg
# /kaggle/input/person-face-sketches/train/photos/5458.jpg
# /kaggle/input/person-face-sketches/train/photos/19063.jpg
# /kaggle/input/person-face-sketches/train/photos/4166.jpg
# /kaggle/input/person-face-sketches/train/photos/11641.jpg
# /kaggle/input/person-face-sketches/train/photos/1173.jpg
# /kaggle/input/person-face-sketches/train/photos/6237.jpg
# /kaggle/input/person-face-sketches/train/photos/1790.jpg
# /kaggle/input/person-face-sketches/train/photos/28348.jpg
# /kaggle/input/person-face-sketches/train/photos/26295.jpg
# /kaggle/input/person-face-sketches/train/photos/6000.jpg
# /kaggle/input/person-face-sketches/train/photos/22439.jpg
# /kaggle/input/person-face-sketches/train/photos/15261.jpg
# /kaggle/input/person-face-sketches/train/photos/29660.jpg
# /kaggle/input/person-face-sketches/train/photos/6605.jpg
# /kaggle/input/person-face-sketches/train/photos/6719.jpg
# /kaggle/input/person-face-sketches/train/photos/21118.jpg
# /kaggle/input/person-face-sketches/train/photos/2137.jpg
# /kaggle/input/person-face-sketches/train/photos/27692.jpg
# /kaggle/input/person-face-sketches/train/photos/13952.jpg
# /kaggle/input/person-face-sketches/train/photos/26899.jpg
# /kaggle/input/person-face-sketches/train/photos/3364.jpg
# /kaggle/input/person-face-sketches/train/photos/27539.jpg
# /kaggle/input/person-face-sketches/train/photos/109.jpg
# /kaggle/input/person-face-sketches/train/photos/5998.jpg
# /kaggle/input/person-face-sketches/train/photos/8369.jpg
# /kaggle/input/person-face-sketches/train/photos/2654.jpg
# /kaggle/input/person-face-sketches/train/photos/11265.jpg
# /kaggle/input/person-face-sketches/train/photos/19699.jpg
# /kaggle/input/person-face-sketches/train/photos/20990.jpg
# /kaggle/input/person-face-sketches/train/photos/22606.jpg
# /kaggle/input/person-face-sketches/train/photos/19585.jpg
# /kaggle/input/person-face-sketches/train/photos/1211.jpg
# /kaggle/input/person-face-sketches/train/photos/12679.jpg
# /kaggle/input/person-face-sketches/train/photos/24883.jpg
# /kaggle/input/person-face-sketches/train/photos/8979.jpg
# /kaggle/input/person-face-sketches/train/photos/13287.jpg
# /kaggle/input/person-face-sketches/train/photos/15724.jpg
# /kaggle/input/person-face-sketches/train/photos/3209.jpg
# /kaggle/input/person-face-sketches/train/photos/19715.jpg
# /kaggle/input/person-face-sketches/train/photos/8367.jpg
# /kaggle/input/person-face-sketches/train/photos/24525.jpg
# /kaggle/input/person-face-sketches/train/photos/4812.jpg
# /kaggle/input/person-face-sketches/train/photos/23915.jpg
# /kaggle/input/person-face-sketches/train/photos/17232.jpg
# /kaggle/input/person-face-sketches/train/photos/9037.jpg
# /kaggle/input/person-face-sketches/train/photos/22860.jpg
# /kaggle/input/person-face-sketches/train/photos/8852.jpg
# /kaggle/input/person-face-sketches/train/photos/5330.jpg
# /kaggle/input/person-face-sketches/train/photos/12464.jpg
# /kaggle/input/person-face-sketches/train/photos/13374.jpg
# /kaggle/input/person-face-sketches/train/photos/22366.jpg
# /kaggle/input/person-face-sketches/train/photos/18626.jpg
# /kaggle/input/person-face-sketches/train/photos/20061.jpg
# /kaggle/input/person-face-sketches/train/photos/6715.jpg
# /kaggle/input/person-face-sketches/train/photos/149.jpg
# /kaggle/input/person-face-sketches/train/photos/1488.jpg
# /kaggle/input/person-face-sketches/train/photos/20572.jpg
# /kaggle/input/person-face-sketches/train/photos/28637.jpg
# /kaggle/input/person-face-sketches/train/photos/8026.jpg
# /kaggle/input/person-face-sketches/train/photos/23415.jpg
# /kaggle/input/person-face-sketches/train/photos/11422.jpg
# /kaggle/input/person-face-sketches/train/photos/26432.jpg
# /kaggle/input/person-face-sketches/train/photos/5056.jpg
# /kaggle/input/person-face-sketches/train/photos/24984.jpg
# /kaggle/input/person-face-sketches/train/photos/13880.jpg
# /kaggle/input/person-face-sketches/train/photos/24865.jpg
# /kaggle/input/person-face-sketches/train/photos/17244.jpg
# /kaggle/input/person-face-sketches/train/photos/9135.jpg
# /kaggle/input/person-face-sketches/train/photos/26261.jpg
# /kaggle/input/person-face-sketches/train/photos/1862.jpg
# /kaggle/input/person-face-sketches/train/photos/1167.jpg
# /kaggle/input/person-face-sketches/train/photos/1644.jpg
# /kaggle/input/person-face-sketches/train/photos/1539.jpg
# /kaggle/input/person-face-sketches/train/photos/10643.jpg
# /kaggle/input/person-face-sketches/train/photos/4494.jpg
# /kaggle/input/person-face-sketches/train/photos/14730.jpg
# /kaggle/input/person-face-sketches/train/photos/17965.jpg
# /kaggle/input/person-face-sketches/train/photos/12424.jpg
# /kaggle/input/person-face-sketches/train/photos/20839.jpg
# /kaggle/input/person-face-sketches/train/photos/20687.jpg
# /kaggle/input/person-face-sketches/train/photos/4373.jpg
# /kaggle/input/person-face-sketches/train/photos/21375.jpg
# /kaggle/input/person-face-sketches/train/photos/187.jpg
# /kaggle/input/person-face-sketches/train/photos/17490.jpg
# /kaggle/input/person-face-sketches/train/photos/521.jpg
# /kaggle/input/person-face-sketches/train/photos/16528.jpg
# /kaggle/input/person-face-sketches/train/photos/17840.jpg
# /kaggle/input/person-face-sketches/train/photos/27558.jpg
# /kaggle/input/person-face-sketches/train/photos/12739.jpg
# /kaggle/input/person-face-sketches/train/photos/10500.jpg
# /kaggle/input/person-face-sketches/train/photos/17103.jpg
# /kaggle/input/person-face-sketches/train/photos/12141.jpg
# /kaggle/input/person-face-sketches/train/photos/14259.jpg
# /kaggle/input/person-face-sketches/train/photos/19654.jpg
# /kaggle/input/person-face-sketches/train/photos/6203.jpg
# /kaggle/input/person-face-sketches/train/photos/25864.jpg
# /kaggle/input/person-face-sketches/train/photos/8112.jpg
# /kaggle/input/person-face-sketches/train/photos/12165.jpg
# /kaggle/input/person-face-sketches/train/photos/28994.jpg
# /kaggle/input/person-face-sketches/train/photos/12272.jpg
# /kaggle/input/person-face-sketches/train/photos/20222.jpg
# /kaggle/input/person-face-sketches/train/photos/76.jpg
# /kaggle/input/person-face-sketches/train/photos/21585.jpg
# /kaggle/input/person-face-sketches/train/photos/15036.jpg
# /kaggle/input/person-face-sketches/train/photos/21706.jpg
# /kaggle/input/person-face-sketches/train/photos/539.jpg
# /kaggle/input/person-face-sketches/train/photos/12759.jpg
# /kaggle/input/person-face-sketches/train/photos/3330.jpg
# /kaggle/input/person-face-sketches/train/photos/2844.jpg
# /kaggle/input/person-face-sketches/train/photos/5817.jpg
# /kaggle/input/person-face-sketches/train/photos/24653.jpg
# /kaggle/input/person-face-sketches/train/photos/29225.jpg
# /kaggle/input/person-face-sketches/train/photos/28320.jpg
# /kaggle/input/person-face-sketches/train/photos/5132.jpg
# /kaggle/input/person-face-sketches/train/photos/17916.jpg
# /kaggle/input/person-face-sketches/train/photos/15027.jpg
# /kaggle/input/person-face-sketches/train/photos/5943.jpg
# /kaggle/input/person-face-sketches/train/photos/3732.jpg
# /kaggle/input/person-face-sketches/train/photos/28252.jpg
# /kaggle/input/person-face-sketches/train/photos/6213.jpg
# /kaggle/input/person-face-sketches/train/photos/24829.jpg
# /kaggle/input/person-face-sketches/train/photos/23424.jpg
# /kaggle/input/person-face-sketches/train/photos/1355.jpg
# /kaggle/input/person-face-sketches/train/photos/27445.jpg
# /kaggle/input/person-face-sketches/train/photos/355.jpg
# /kaggle/input/person-face-sketches/train/photos/29934.jpg
# /kaggle/input/person-face-sketches/train/photos/29026.jpg
# /kaggle/input/person-face-sketches/train/photos/26125.jpg
# /kaggle/input/person-face-sketches/train/photos/24630.jpg
# /kaggle/input/person-face-sketches/train/photos/17799.jpg
# /kaggle/input/person-face-sketches/train/photos/11763.jpg
# /kaggle/input/person-face-sketches/train/photos/2899.jpg
# /kaggle/input/person-face-sketches/train/photos/17211.jpg
# /kaggle/input/person-face-sketches/train/photos/16013.jpg
# /kaggle/input/person-face-sketches/train/photos/10538.jpg
# /kaggle/input/person-face-sketches/train/photos/22039.jpg
# /kaggle/input/person-face-sketches/train/photos/5117.jpg
# /kaggle/input/person-face-sketches/train/photos/22254.jpg
# /kaggle/input/person-face-sketches/train/photos/25952.jpg
# /kaggle/input/person-face-sketches/train/photos/12374.jpg
# /kaggle/input/person-face-sketches/train/photos/22932.jpg
# /kaggle/input/person-face-sketches/train/photos/28042.jpg
# /kaggle/input/person-face-sketches/train/photos/18226.jpg
# /kaggle/input/person-face-sketches/train/photos/16733.jpg
# /kaggle/input/person-face-sketches/train/photos/12959.jpg
# /kaggle/input/person-face-sketches/train/photos/9222.jpg
# /kaggle/input/person-face-sketches/train/photos/15621.jpg
# /kaggle/input/person-face-sketches/train/photos/22019.jpg
# /kaggle/input/person-face-sketches/train/photos/15370.jpg
# /kaggle/input/person-face-sketches/train/photos/8555.jpg
# /kaggle/input/person-face-sketches/train/photos/8380.jpg
# /kaggle/input/person-face-sketches/train/photos/3546.jpg
# /kaggle/input/person-face-sketches/train/photos/9364.jpg
# /kaggle/input/person-face-sketches/train/photos/14104.jpg
# /kaggle/input/person-face-sketches/train/photos/10383.jpg
# /kaggle/input/person-face-sketches/train/photos/14021.jpg
# /kaggle/input/person-face-sketches/train/photos/29382.jpg
# /kaggle/input/person-face-sketches/train/photos/27428.jpg
# /kaggle/input/person-face-sketches/train/photos/1409.jpg
# /kaggle/input/person-face-sketches/train/photos/4039.jpg
# /kaggle/input/person-face-sketches/train/photos/71.jpg
# /kaggle/input/person-face-sketches/train/photos/24336.jpg
# /kaggle/input/person-face-sketches/train/photos/21034.jpg
# /kaggle/input/person-face-sketches/train/photos/7296.jpg
# /kaggle/input/person-face-sketches/train/photos/22682.jpg
# /kaggle/input/person-face-sketches/train/photos/22176.jpg
# /kaggle/input/person-face-sketches/train/photos/708.jpg
# /kaggle/input/person-face-sketches/train/photos/3539.jpg
# /kaggle/input/person-face-sketches/train/photos/1222.jpg
# /kaggle/input/person-face-sketches/train/photos/4986.jpg
# /kaggle/input/person-face-sketches/train/photos/1154.jpg
# /kaggle/input/person-face-sketches/train/photos/3743.jpg
# /kaggle/input/person-face-sketches/train/photos/16087.jpg
# /kaggle/input/person-face-sketches/train/photos/13030.jpg
# /kaggle/input/person-face-sketches/train/photos/4188.jpg
# /kaggle/input/person-face-sketches/train/photos/17550.jpg
# /kaggle/input/person-face-sketches/train/photos/27203.jpg
# /kaggle/input/person-face-sketches/train/photos/27707.jpg
# /kaggle/input/person-face-sketches/train/photos/13723.jpg
# /kaggle/input/person-face-sketches/train/photos/18612.jpg
# /kaggle/input/person-face-sketches/train/photos/9331.jpg
# /kaggle/input/person-face-sketches/train/photos/7338.jpg
# /kaggle/input/person-face-sketches/train/photos/18545.jpg
# /kaggle/input/person-face-sketches/train/photos/19791.jpg
# /kaggle/input/person-face-sketches/train/photos/474.jpg
# /kaggle/input/person-face-sketches/train/photos/15374.jpg
# /kaggle/input/person-face-sketches/train/photos/26880.jpg
# /kaggle/input/person-face-sketches/train/photos/18771.jpg
# /kaggle/input/person-face-sketches/train/photos/20917.jpg
# /kaggle/input/person-face-sketches/train/photos/19526.jpg
# /kaggle/input/person-face-sketches/train/photos/10405.jpg
# /kaggle/input/person-face-sketches/train/photos/5386.jpg
# /kaggle/input/person-face-sketches/train/photos/18273.jpg
# /kaggle/input/person-face-sketches/train/photos/29061.jpg
# /kaggle/input/person-face-sketches/train/photos/20313.jpg
# /kaggle/input/person-face-sketches/train/photos/9562.jpg
# /kaggle/input/person-face-sketches/train/photos/29515.jpg
# /kaggle/input/person-face-sketches/train/photos/1840.jpg
# /kaggle/input/person-face-sketches/train/photos/24987.jpg
# /kaggle/input/person-face-sketches/train/photos/14610.jpg
# /kaggle/input/person-face-sketches/train/photos/22444.jpg
# /kaggle/input/person-face-sketches/train/photos/28240.jpg
# /kaggle/input/person-face-sketches/train/photos/8691.jpg
# /kaggle/input/person-face-sketches/train/photos/25077.jpg
# /kaggle/input/person-face-sketches/train/photos/3996.jpg
# /kaggle/input/person-face-sketches/train/photos/3574.jpg
# /kaggle/input/person-face-sketches/train/photos/20719.jpg
# /kaggle/input/person-face-sketches/train/photos/25289.jpg
# /kaggle/input/person-face-sketches/train/photos/29684.jpg
# /kaggle/input/person-face-sketches/train/photos/26793.jpg
# /kaggle/input/person-face-sketches/train/photos/26067.jpg
# /kaggle/input/person-face-sketches/train/photos/29641.jpg
# /kaggle/input/person-face-sketches/train/photos/29217.jpg
# /kaggle/input/person-face-sketches/train/photos/19491.jpg
# /kaggle/input/person-face-sketches/train/photos/9896.jpg
# /kaggle/input/person-face-sketches/train/photos/28714.jpg
# /kaggle/input/person-face-sketches/train/photos/11397.jpg
# /kaggle/input/person-face-sketches/train/photos/21095.jpg
# /kaggle/input/person-face-sketches/train/photos/9800.jpg
# /kaggle/input/person-face-sketches/train/photos/27931.jpg
# /kaggle/input/person-face-sketches/train/photos/22229.jpg
# /kaggle/input/person-face-sketches/train/photos/27198.jpg
# /kaggle/input/person-face-sketches/train/photos/17759.jpg
# /kaggle/input/person-face-sketches/train/photos/7815.jpg
# /kaggle/input/person-face-sketches/train/photos/8739.jpg
# /kaggle/input/person-face-sketches/train/photos/7012.jpg
# /kaggle/input/person-face-sketches/train/photos/17015.jpg
# /kaggle/input/person-face-sketches/train/photos/27550.jpg
# /kaggle/input/person-face-sketches/train/photos/6682.jpg
# /kaggle/input/person-face-sketches/train/photos/10058.jpg
# /kaggle/input/person-face-sketches/train/photos/10573.jpg
# /kaggle/input/person-face-sketches/train/photos/15706.jpg
# /kaggle/input/person-face-sketches/train/photos/1124.jpg
# /kaggle/input/person-face-sketches/train/photos/7744.jpg
# /kaggle/input/person-face-sketches/train/photos/501.jpg
# /kaggle/input/person-face-sketches/train/photos/23049.jpg
# /kaggle/input/person-face-sketches/train/photos/28599.jpg
# /kaggle/input/person-face-sketches/train/photos/16500.jpg
# /kaggle/input/person-face-sketches/train/photos/5240.jpg
# /kaggle/input/person-face-sketches/train/photos/24792.jpg
# /kaggle/input/person-face-sketches/train/photos/1395.jpg
# /kaggle/input/person-face-sketches/train/photos/19012.jpg
# /kaggle/input/person-face-sketches/train/photos/29264.jpg
# /kaggle/input/person-face-sketches/train/photos/22070.jpg
# /kaggle/input/person-face-sketches/train/photos/20865.jpg
# /kaggle/input/person-face-sketches/train/photos/3823.jpg
# /kaggle/input/person-face-sketches/train/photos/20375.jpg
# /kaggle/input/person-face-sketches/train/photos/15674.jpg
# /kaggle/input/person-face-sketches/train/photos/14151.jpg
# /kaggle/input/person-face-sketches/train/photos/3467.jpg
# /kaggle/input/person-face-sketches/train/photos/26536.jpg
# /kaggle/input/person-face-sketches/train/photos/2363.jpg
# /kaggle/input/person-face-sketches/train/photos/9733.jpg
# /kaggle/input/person-face-sketches/train/photos/5641.jpg
# /kaggle/input/person-face-sketches/train/photos/25097.jpg
# /kaggle/input/person-face-sketches/train/photos/815.jpg
# /kaggle/input/person-face-sketches/train/photos/16389.jpg
# /kaggle/input/person-face-sketches/train/photos/9634.jpg
# /kaggle/input/person-face-sketches/train/photos/14649.jpg
# /kaggle/input/person-face-sketches/train/photos/20070.jpg
# /kaggle/input/person-face-sketches/train/photos/20371.jpg
# /kaggle/input/person-face-sketches/train/photos/21859.jpg
# /kaggle/input/person-face-sketches/train/photos/21644.jpg
# /kaggle/input/person-face-sketches/train/photos/3654.jpg
# /kaggle/input/person-face-sketches/train/photos/9148.jpg
# /kaggle/input/person-face-sketches/train/photos/21577.jpg
# /kaggle/input/person-face-sketches/train/photos/9464.jpg
# /kaggle/input/person-face-sketches/train/photos/6574.jpg
# /kaggle/input/person-face-sketches/train/photos/17282.jpg
# /kaggle/input/person-face-sketches/train/photos/23859.jpg
# /kaggle/input/person-face-sketches/train/photos/28944.jpg
# /kaggle/input/person-face-sketches/train/photos/342.jpg
# /kaggle/input/person-face-sketches/train/photos/21761.jpg
# /kaggle/input/person-face-sketches/train/photos/29155.jpg
# /kaggle/input/person-face-sketches/train/photos/26508.jpg
# /kaggle/input/person-face-sketches/train/photos/8554.jpg
# /kaggle/input/person-face-sketches/train/photos/11756.jpg
# /kaggle/input/person-face-sketches/train/photos/11552.jpg
# /kaggle/input/person-face-sketches/train/photos/5192.jpg
# /kaggle/input/person-face-sketches/train/photos/1459.jpg
# /kaggle/input/person-face-sketches/train/photos/23461.jpg
# /kaggle/input/person-face-sketches/train/photos/8130.jpg
# /kaggle/input/person-face-sketches/train/photos/14020.jpg
# /kaggle/input/person-face-sketches/train/photos/8440.jpg
# /kaggle/input/person-face-sketches/train/photos/2704.jpg
# /kaggle/input/person-face-sketches/train/photos/817.jpg
# /kaggle/input/person-face-sketches/train/photos/8719.jpg
# /kaggle/input/person-face-sketches/train/photos/10089.jpg
# /kaggle/input/person-face-sketches/train/photos/21326.jpg
# /kaggle/input/person-face-sketches/train/photos/25958.jpg
# /kaggle/input/person-face-sketches/train/photos/8478.jpg
# /kaggle/input/person-face-sketches/train/photos/8013.jpg
# /kaggle/input/person-face-sketches/train/photos/20119.jpg
# /kaggle/input/person-face-sketches/train/photos/9114.jpg
# /kaggle/input/person-face-sketches/train/photos/23482.jpg
# /kaggle/input/person-face-sketches/train/photos/25090.jpg
# /kaggle/input/person-face-sketches/train/photos/5475.jpg
# /kaggle/input/person-face-sketches/train/photos/8906.jpg
# /kaggle/input/person-face-sketches/train/photos/6404.jpg
# /kaggle/input/person-face-sketches/train/photos/6986.jpg
# /kaggle/input/person-face-sketches/train/photos/13997.jpg
# /kaggle/input/person-face-sketches/train/photos/14237.jpg
# /kaggle/input/person-face-sketches/train/photos/24923.jpg
# /kaggle/input/person-face-sketches/train/photos/13495.jpg
# /kaggle/input/person-face-sketches/train/photos/6470.jpg
# /kaggle/input/person-face-sketches/train/photos/17851.jpg
# /kaggle/input/person-face-sketches/train/photos/11729.jpg
# /kaggle/input/person-face-sketches/train/photos/9549.jpg
# /kaggle/input/person-face-sketches/train/photos/4550.jpg
# /kaggle/input/person-face-sketches/train/photos/28448.jpg
# /kaggle/input/person-face-sketches/train/photos/3802.jpg
# /kaggle/input/person-face-sketches/train/photos/6036.jpg
# /kaggle/input/person-face-sketches/train/photos/9750.jpg
# /kaggle/input/person-face-sketches/train/photos/17896.jpg
# /kaggle/input/person-face-sketches/train/photos/13371.jpg
# /kaggle/input/person-face-sketches/train/photos/4706.jpg
# /kaggle/input/person-face-sketches/train/photos/27432.jpg
# /kaggle/input/person-face-sketches/train/photos/19250.jpg
# /kaggle/input/person-face-sketches/train/photos/16236.jpg
# /kaggle/input/person-face-sketches/train/photos/20160.jpg
# /kaggle/input/person-face-sketches/train/photos/17494.jpg
# /kaggle/input/person-face-sketches/train/photos/20383.jpg
# /kaggle/input/person-face-sketches/train/photos/26976.jpg
# /kaggle/input/person-face-sketches/train/photos/15923.jpg
# /kaggle/input/person-face-sketches/train/photos/429.jpg
# /kaggle/input/person-face-sketches/train/photos/9088.jpg
# /kaggle/input/person-face-sketches/train/photos/17354.jpg
# /kaggle/input/person-face-sketches/train/photos/17907.jpg
# /kaggle/input/person-face-sketches/train/photos/15638.jpg
# /kaggle/input/person-face-sketches/train/photos/20254.jpg
# /kaggle/input/person-face-sketches/train/photos/4955.jpg
# /kaggle/input/person-face-sketches/train/photos/4757.jpg
# /kaggle/input/person-face-sketches/train/photos/3684.jpg
# /kaggle/input/person-face-sketches/train/photos/20004.jpg
# /kaggle/input/person-face-sketches/train/photos/28149.jpg
# /kaggle/input/person-face-sketches/train/photos/28585.jpg
# /kaggle/input/person-face-sketches/train/photos/11746.jpg
# /kaggle/input/person-face-sketches/train/photos/15907.jpg
# /kaggle/input/person-face-sketches/train/photos/6097.jpg
# /kaggle/input/person-face-sketches/train/photos/9398.jpg
# /kaggle/input/person-face-sketches/train/photos/5126.jpg
# /kaggle/input/person-face-sketches/train/photos/16838.jpg
# /kaggle/input/person-face-sketches/train/photos/9004.jpg
# /kaggle/input/person-face-sketches/train/photos/25388.jpg
# /kaggle/input/person-face-sketches/train/photos/8948.jpg
# /kaggle/input/person-face-sketches/train/photos/21536.jpg
# /kaggle/input/person-face-sketches/train/photos/21385.jpg
# /kaggle/input/person-face-sketches/train/photos/28100.jpg
# /kaggle/input/person-face-sketches/train/photos/25678.jpg
# /kaggle/input/person-face-sketches/train/photos/20800.jpg
# /kaggle/input/person-face-sketches/train/photos/24673.jpg
# /kaggle/input/person-face-sketches/train/photos/13821.jpg
# /kaggle/input/person-face-sketches/train/photos/1055.jpg
# /kaggle/input/person-face-sketches/train/photos/24445.jpg
# /kaggle/input/person-face-sketches/train/photos/25291.jpg
# /kaggle/input/person-face-sketches/train/photos/29931.jpg
# /kaggle/input/person-face-sketches/train/photos/19366.jpg
# /kaggle/input/person-face-sketches/train/photos/17223.jpg
# /kaggle/input/person-face-sketches/train/photos/2560.jpg
# /kaggle/input/person-face-sketches/train/photos/18123.jpg
# /kaggle/input/person-face-sketches/train/photos/6262.jpg
# /kaggle/input/person-face-sketches/train/photos/29314.jpg
# /kaggle/input/person-face-sketches/train/photos/14246.jpg
# /kaggle/input/person-face-sketches/train/photos/16468.jpg
# /kaggle/input/person-face-sketches/train/photos/6281.jpg
# /kaggle/input/person-face-sketches/train/photos/28955.jpg
# /kaggle/input/person-face-sketches/train/photos/18274.jpg
# /kaggle/input/person-face-sketches/train/photos/4642.jpg
# /kaggle/input/person-face-sketches/train/photos/25387.jpg
# /kaggle/input/person-face-sketches/train/photos/18514.jpg
# /kaggle/input/person-face-sketches/train/photos/22768.jpg
# /kaggle/input/person-face-sketches/train/photos/13443.jpg
# /kaggle/input/person-face-sketches/train/photos/24514.jpg
# /kaggle/input/person-face-sketches/train/photos/24849.jpg
# /kaggle/input/person-face-sketches/train/photos/13893.jpg
# /kaggle/input/person-face-sketches/train/photos/27161.jpg
# /kaggle/input/person-face-sketches/train/photos/10057.jpg
# /kaggle/input/person-face-sketches/train/photos/16846.jpg
# /kaggle/input/person-face-sketches/train/photos/7611.jpg
# /kaggle/input/person-face-sketches/train/photos/4939.jpg
# /kaggle/input/person-face-sketches/train/photos/14535.jpg
# /kaggle/input/person-face-sketches/train/photos/26800.jpg
# /kaggle/input/person-face-sketches/train/photos/8794.jpg
# /kaggle/input/person-face-sketches/train/photos/18624.jpg
# /kaggle/input/person-face-sketches/train/photos/15895.jpg
# /kaggle/input/person-face-sketches/train/photos/24165.jpg
# /kaggle/input/person-face-sketches/train/photos/4482.jpg
# /kaggle/input/person-face-sketches/train/photos/27748.jpg
# /kaggle/input/person-face-sketches/train/photos/22512.jpg
# /kaggle/input/person-face-sketches/train/photos/14862.jpg
# /kaggle/input/person-face-sketches/train/photos/18158.jpg
# /kaggle/input/person-face-sketches/train/photos/21968.jpg
# /kaggle/input/person-face-sketches/train/photos/11099.jpg
# /kaggle/input/person-face-sketches/train/photos/29873.jpg
# /kaggle/input/person-face-sketches/train/photos/682.jpg
# /kaggle/input/person-face-sketches/train/photos/9032.jpg
# /kaggle/input/person-face-sketches/train/photos/28023.jpg
# /kaggle/input/person-face-sketches/train/photos/19163.jpg
# /kaggle/input/person-face-sketches/train/photos/23894.jpg
# /kaggle/input/person-face-sketches/train/photos/14950.jpg
# /kaggle/input/person-face-sketches/train/photos/4369.jpg
# /kaggle/input/person-face-sketches/train/photos/6455.jpg
# /kaggle/input/person-face-sketches/train/photos/6502.jpg
# /kaggle/input/person-face-sketches/train/photos/27772.jpg
# /kaggle/input/person-face-sketches/train/photos/3198.jpg
# /kaggle/input/person-face-sketches/train/photos/12810.jpg
# /kaggle/input/person-face-sketches/train/photos/28468.jpg
# /kaggle/input/person-face-sketches/train/photos/18369.jpg
# /kaggle/input/person-face-sketches/train/photos/16554.jpg
# /kaggle/input/person-face-sketches/train/photos/3322.jpg
# /kaggle/input/person-face-sketches/train/photos/5122.jpg
# /kaggle/input/person-face-sketches/train/photos/5334.jpg
# /kaggle/input/person-face-sketches/train/photos/544.jpg
# /kaggle/input/person-face-sketches/train/photos/1794.jpg
# /kaggle/input/person-face-sketches/train/photos/1715.jpg
# /kaggle/input/person-face-sketches/train/photos/15580.jpg
# /kaggle/input/person-face-sketches/train/photos/2953.jpg
# /kaggle/input/person-face-sketches/train/photos/24258.jpg
# /kaggle/input/person-face-sketches/train/photos/22265.jpg
# /kaggle/input/person-face-sketches/train/photos/377.jpg
# /kaggle/input/person-face-sketches/train/photos/15114.jpg
# /kaggle/input/person-face-sketches/train/photos/25140.jpg
# /kaggle/input/person-face-sketches/train/photos/16617.jpg
# /kaggle/input/person-face-sketches/train/photos/1026.jpg
# /kaggle/input/person-face-sketches/train/photos/17217.jpg
# /kaggle/input/person-face-sketches/train/photos/20436.jpg
# /kaggle/input/person-face-sketches/train/photos/13660.jpg
# /kaggle/input/person-face-sketches/train/photos/24996.jpg
# /kaggle/input/person-face-sketches/train/photos/18413.jpg
# /kaggle/input/person-face-sketches/train/photos/14055.jpg
# /kaggle/input/person-face-sketches/train/photos/23303.jpg
# /kaggle/input/person-face-sketches/train/photos/21652.jpg
# /kaggle/input/person-face-sketches/train/photos/17065.jpg
# /kaggle/input/person-face-sketches/train/photos/272.jpg
# /kaggle/input/person-face-sketches/train/photos/27443.jpg
# /kaggle/input/person-face-sketches/train/photos/795.jpg
# /kaggle/input/person-face-sketches/train/photos/20881.jpg
# /kaggle/input/person-face-sketches/train/photos/18987.jpg
# /kaggle/input/person-face-sketches/train/photos/25821.jpg
# /kaggle/input/person-face-sketches/train/photos/16525.jpg
# /kaggle/input/person-face-sketches/train/photos/29043.jpg
# /kaggle/input/person-face-sketches/train/photos/24881.jpg
# /kaggle/input/person-face-sketches/train/photos/18337.jpg
# /kaggle/input/person-face-sketches/train/photos/270.jpg
# /kaggle/input/person-face-sketches/train/photos/23854.jpg
# /kaggle/input/person-face-sketches/train/photos/26462.jpg
# /kaggle/input/person-face-sketches/train/photos/28103.jpg
# /kaggle/input/person-face-sketches/train/photos/3968.jpg
# /kaggle/input/person-face-sketches/train/photos/13353.jpg
# /kaggle/input/person-face-sketches/train/photos/12473.jpg
# /kaggle/input/person-face-sketches/train/photos/3221.jpg
# /kaggle/input/person-face-sketches/train/photos/3884.jpg
# /kaggle/input/person-face-sketches/train/photos/15217.jpg
# /kaggle/input/person-face-sketches/train/photos/8816.jpg
# /kaggle/input/person-face-sketches/train/photos/18707.jpg
# /kaggle/input/person-face-sketches/train/photos/28951.jpg
# /kaggle/input/person-face-sketches/train/photos/14150.jpg
# /kaggle/input/person-face-sketches/train/photos/24952.jpg
# /kaggle/input/person-face-sketches/train/photos/24812.jpg
# /kaggle/input/person-face-sketches/train/photos/6775.jpg
# /kaggle/input/person-face-sketches/train/photos/7904.jpg
# /kaggle/input/person-face-sketches/train/photos/23454.jpg
# /kaggle/input/person-face-sketches/train/photos/25766.jpg
# /kaggle/input/person-face-sketches/train/photos/11278.jpg
# /kaggle/input/person-face-sketches/train/photos/1936.jpg
# /kaggle/input/person-face-sketches/train/photos/26961.jpg
# /kaggle/input/person-face-sketches/train/photos/1162.jpg
# /kaggle/input/person-face-sketches/train/photos/21042.jpg
# /kaggle/input/person-face-sketches/train/photos/4766.jpg
# /kaggle/input/person-face-sketches/train/photos/7549.jpg
# /kaggle/input/person-face-sketches/train/photos/14330.jpg
# /kaggle/input/person-face-sketches/train/photos/23898.jpg
# /kaggle/input/person-face-sketches/train/photos/10452.jpg
# /kaggle/input/person-face-sketches/train/photos/3713.jpg
# /kaggle/input/person-face-sketches/train/photos/17607.jpg
# /kaggle/input/person-face-sketches/train/photos/13274.jpg
# /kaggle/input/person-face-sketches/train/photos/27839.jpg
# /kaggle/input/person-face-sketches/train/photos/19374.jpg
# /kaggle/input/person-face-sketches/train/photos/22743.jpg
# /kaggle/input/person-face-sketches/train/photos/9298.jpg
# /kaggle/input/person-face-sketches/train/photos/23995.jpg
# /kaggle/input/person-face-sketches/train/photos/13714.jpg
# /kaggle/input/person-face-sketches/train/photos/26931.jpg
# /kaggle/input/person-face-sketches/train/photos/3195.jpg
# /kaggle/input/person-face-sketches/train/photos/23483.jpg
# /kaggle/input/person-face-sketches/train/photos/19405.jpg
# /kaggle/input/person-face-sketches/train/photos/215.jpg
# /kaggle/input/person-face-sketches/train/photos/22943.jpg
# /kaggle/input/person-face-sketches/train/photos/6732.jpg
# /kaggle/input/person-face-sketches/train/photos/14635.jpg
# /kaggle/input/person-face-sketches/train/photos/29358.jpg
# /kaggle/input/person-face-sketches/train/photos/7659.jpg
# /kaggle/input/person-face-sketches/train/photos/5465.jpg
# /kaggle/input/person-face-sketches/train/photos/13450.jpg
# /kaggle/input/person-face-sketches/train/photos/5649.jpg
# /kaggle/input/person-face-sketches/train/photos/21319.jpg
